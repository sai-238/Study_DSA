# %%
from urllib import request
import re

# %%
class WebCrawler:
    def __init__(self):
        self.discovered_websites = []

    # BFS implementation
    def crawl(self, start_url):
        queue = [start_url]
        self.discovered_websites.append(start_url)

        while queue:
            actual_url = queue.pop(0)
            print(actual_url)

            # This is the raw HTML representation of the website (URL)
            actual_url_html = self.read_raw_html(actual_url)

            if actual_url_html:
                for url in self.get_links_from_html(actual_url_html):
                    if url not in self.discovered_websites:
                        self.discovered_websites.append(url)
                        queue.append(url)

    def get_links_from_html(self, raw_html):
        return re.findall(r'https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', raw_html)

    def read_raw_html(self, url):
        raw_html = " "

        try:
            response = request.urlopen(url)
            raw_html = response.read().decode('utf-8')
        except Exception as e:
            pass

        return raw_html

# %%
crawler = WebCrawler()
crawler.crawl('https://neetcode.io')
# Out:
# https://neetcode.io
# https://connect.facebook.net
# https://www.facebook.com
# https://m.facebook.com
# https://static.xx.fbcdn.net
# https://ur-pk.facebook.com
# https://mr-in.facebook.com
# https://te-in.facebook.com
# https://hi-in.facebook.com
# https://ta-in.facebook.com
# https://ml-in.facebook.com
# https://bn-in.facebook.com
# https://gu-in.facebook.com
# https://pa-in.facebook.com
# https://en-gb.facebook.com
# https://messenger.com
# https://pay.facebook.com
# https://www.meta.com
# https://l.facebook.com
# https://about.meta.com
# https://developers.facebook.com
# https://facebook.com
# https://pixel.facebook.com
# http://www.wapforum.org
# http://www.w3.org
# https://kn-in.facebook.com
# https://www.messenger.com
# https://scontent.fblr1-6.fna.fbcdn.net
# http://l.messenger.com
# https://l.messenger.com
# https://scontent.fblr1-5.fna.fbcdn.net
# https://scontent.fblr1-3.fna.fbcdn.net
# https://video.fblr1-8.fna.fbcdn.net
# https://scontent.fblr1-4.fna.fbcdn.net
# https://scontent.fblr1-8.fna.fbcdn.net
# https://scontent.fblr1-9.fna.fbcdn.net
# https://www.oculus.com
# https://creator.oculus.com
# https://developer.oculus.com
# https://edge-chat.facebook.com
# https://scontent.fblr1-7.fna.fbcdn.net
# https://about.facebook.com
# https://www.w3.org
# https://github.com
# https://www.youtube.com
# https://status.w3.org
# https://w3c.social
# https://twitter.com
# https://graph.oculus.com
# https://github.githubassets.com
# https://avatars.githubusercontent.com
# https://github-cloud.s3.amazonaws.com
# https://user-images.githubusercontent.com
# https://collector.github.com
# https://hachyderm.io
# https://api.github.com
# https://docs.github.com
# https://skills.github.com
# https://github.blog
# https://education.github.com
# https://resources.github.com
# https://partner.github.com
# https://githubuniverse.com
# https://www.electronjs.org
# https://desktop.github.com
# https://github.community
# https://services.github.com
# https://www.githubstatus.com
# https://support.github.com
# https://socialimpact.github.com
# https://shop.github.com
# https://x.com
# https://www.linkedin.com
# https://www.twitch.tv
# https://www.tiktok.com
# https://m.youtube.com
# https://i.ytimg.com
# https://www.gstatic.com
# https://apis.google.com
# https://accounts.google.com
# https://payments.youtube.com
# https://families.google.com
# https://client-channel.google.com
# https://clients4.google.com
# https://studio.youtube.com
# https://support.google.com
# https://accountlinking-pa-clients6.youtube.com
# https://www.google.com
# https://www.google.co.in
# https://developers.google.com
# https://rr6---sn-ci5gup-cagd.googlevideo.com
# https://yt3.ggpht.com
# https://rr8---sn-ci5gup-cagr.googlevideo.com
# https://rr5---sn-ci5gup-cagd.googlevideo.com
# https://rr3---sn-ci5gup-cagl.googlevideo.com
# https://rr4---sn-ci5gup-cagr.googlevideo.com
# https://rr7---sn-ci5gup-cagr.googlevideo.com
# https://rr8---sn-ci5gup-cagl.googlevideo.com
# https://rr7---sn-ci5gup-cagk.googlevideo.com
# https://rr3---sn-ci5gup-cagd.googlevideo.com
# https://rr6---sn-ci5gup-cagr.googlevideo.com
# https://www.youtubefanfest.com
# https://www.instagram.com
# https://twitt...
# https://rr8---sn-ci5gup-cagz.googlevideo.com
# https://twit...
# https://rr1---sn-ci5gup-cagl.googlevideo.com
# https://www....
# https://rr3---sn-ci5gup-cagr.googlevideo.com
# https://twitter.com...
# https://rr2---sn-ci5gup-cagl.googlevideo.com
# https://rr6---sn-ci5gup-cagz.googlevideo.com
# https://cutt.ly
# https://rr3---sn-ci5gup-cagz.googlevideo.com
# https://rr2---sn-ci5gup-cagk.googlevideo.com
# https://rr1---sn-ci5gup-cagr.googlevideo.com
# https://rr2---sn-ci5gup-cag6.googlevideo.com
# https://bit.ly
# https://rr8---sn-ci5gup-cagd.googlevideo.com
# https://rr2---sn-ci5gup-cagd.googlevideo.com
# https://rr4---sn-ci5gup-cags.googlevideo.com
# https://rr2---sn-ci5gup-cagr.googlevideo.com
# https://rr7---sn-ci5gup-cagd.googlevideo.com
# https://rr5---sn-ci5gup-cagr.googlevideo.com
# https://rr5---sn-ci5gup-cagk.googlevideo.com
# https://out-now.lnk.to
# https://rr6---sn-ci5gup-cagl.googlevideo.com
# https://maha...
# https://rr1---sn-ci5gup-cag6.googlevideo.com
# https://rr1---sn-ci5gup-cagk.googlevideo.com
# https://youtube.com
# https://www.googleadservices.com
# https://www.croma.com
# http://purl.org
# https://dka575ofm4ao0.cloudfront.net
# https://polyfill.io
# https://policies.google.com
# https://www.atlassian.com
# https://subscriptions.statuspage.io
# https://community.atlassian.com
# https://lists.w3.org
# https://api.w3.org
# https://chapters.w3.org
# https://www.recaptcha.net
# https://w3csocial.files.fedi.monster
# https://joinmastodon.org
# https://abs.twimg.com
# https://twitter3e4tixl4xyajtrzo62zg5vztmjuricljdp2c5kshju4avyoid.onion
# https://static.ads-twitter.com
# https://help.twitter.com
# https://support.twitter.com
# https://legal.twitter.com
# https://business.twitter.com
# https://media.hachyderm.io
# https://status.hachyderm.io
# https://ghdocs-prod.azurewebsites.net
# https://electronjs.org
# https://codeql.github.com
# https://docs.npmjs.com
# https://enterprise.github.com
# https://unpkg.com
# https://gmpg.org
# https://yoast.com
# https://schema.org
# https://api.w.org
# https://wp.me
# https://collector.githubapp.com
# https://avatars1.githubusercontent.com
# https://s88570519.t.eloqua.com
# https://developer.github.com
# https://atom.io
# https://analytics.githubassets.com
# https://stats.wp.com
# https://classroom.github.com
# https://twitch.tv
# http://partner.github.com
# https://githubstatus.com
# https://images.ctfassets.net
# https://marketing-forms-api.github.com
# https://ajax.googleapis.com
# https://rsms.me
# https://cdn.jsdelivr.net
# https://opensource.guide
# https://reg.githubuniverse.com
# https://www.microsoft.com
# https://www.arm.com
# https://www.docker.com
# https://www.postman.com
# https://octopus.com
# https://www.datadoghq.com
# https://events.xebia.com
# https://readme.com
# https://www.evinced.com
# https://www.redhat.com
# https://www.swimm.io
# https://1password.com
# https://www.endorlabs.com
# https://pangea.cloud
# https://www.pixee.ai
# https://www.mend.io
# https://www.tricentis.com
# https://www.atmosera.com
# https://trunk.io
# https://www.paypal.com
# https://apwr.dev
# https://www.stacklok.com
# https://boxboat.com
# https://MG3SRMK3K0-dsn.algolia.net
# https://docusaurus.io
# https://www.google-analytics.com
# https://electronforge.io
# https://releases.electronjs.org
# https://openjsf.org
# https://www.apple.com
# https://snapcraft.io
# https://sentry.io
# https://upload.wikimedia.org
# https://playwright.dev
# https://testing-library.com
# https://asana.com
# https://discord.com
# https://dropbox.com
# https://figma.com
# https://flat.whiteboard.agora.io
# https://itch.io
# https://www.loom.com
# https://www.mongodb.com
# https://www.notion.so
# https://obsidian.md
# https://polypane.app
# https://postman.com
# https://signal.org
# https://skype.com
# https://slack.com
# https://splice.com
# https://microsoft.com
# https://tidal.com
# https://trello.com
# https://code.visualstudio.com
# https://apps.wordpress.com
# https://discordapp.com
# https://social.lfx.dev
# https://stackoverflow.com
# https://opencollective.com
# https://help.github.com
# https://central.github.com
# https://support.apple.com
# http://schema.org
# https://replit.com
# https://stspg.io
# https://support-assets.githubassets.com
# https://guides.github.com
# https://use.typekit.net
# http://electron.atom.io
# https://lab.github.com
# https://github.us11.list-manage.com
# https://www.thegithubshop.com
# https://connect.punchout2go.com
# https://www.googletagmanager.com
# https://static.klaviyo.com
# https://nam11.safelinks.protection.outlook.com
# https://de.linkedin.com
# https://ie.linkedin.com
# https://pt.linkedin.com
# https://il.linkedin.com
# https://my.linkedin.com
# https://in.linkedin.com
# https://bo.linkedin.com
# https://za.linkedin.com
# https://cn.linkedin.com
# https://au.linkedin.com
# https://id.linkedin.com
# https://ng.linkedin.com
# https://ch.linkedin.com
# https://jp.linkedin.com
# https://zw.linkedin.com
# https://jm.linkedin.com
# https://sv.linkedin.com
# https://gt.linkedin.com
# https://cr.linkedin.com
# https://it.linkedin.com
# https://cl.linkedin.com
# https://es.linkedin.com
# https://co.linkedin.com
# https://pe.linkedin.com
# https://ae.linkedin.com
# https://nz.linkedin.com
# https://pa.linkedin.com
# https://sg.linkedin.com
# https://fr.linkedin.com
# https://ro.linkedin.com
# https://uk.linkedin.com
# https://nl.linkedin.com
# https://ke.linkedin.com
# https://no.linkedin.com
# https://ca.linkedin.com
# https://ru.linkedin.com
# https://gh.linkedin.com
# https://pr.linkedin.com
# https://do.linkedin.com
# https://at.linkedin.com
# https://ec.linkedin.com
# https://cz.linkedin.com
# https://ph.linkedin.com
# https://pk.linkedin.com
# https://se.linkedin.com
# https://kr.linkedin.com
# https://tt.linkedin.com
# https://tw.linkedin.com
# https://hk.linkedin.com
# https://br.linkedin.com
# https://uy.linkedin.com
# https://ve.linkedin.com
# https://mx.linkedin.com
# https://ar.linkedin.com
# https://th.linkedin.com
# https://dk.linkedin.com
# https://lu.linkedin.com
# https://pl.linkedin.com
# https://tr.linkedin.com
# https://static.licdn.com
# https://www.youtube-nocookie.com
# https://about.linkedin.com
# https://press.linkedin.com
# https://blog.linkedin.com
# https://developer.linkedin.com
# https://mobile.linkedin.com
# https://business.linkedin.com
# https://learning.linkedin.com
# https://brand.linkedin.com
# https://m.twitch.tv
# https://static-cdn.jtvnw.net
# https://en.wikipedia.org
# https://static.twitchcdn.net
# https://api.twitch.tv
# https://passport.twitch.tv
# https://gql.twitch.tv
# https://cvp.twitch.tv
# https://irc-ws.chat.twitch.tv
# https://pubsub-edge.twitch.tv
# https://spade.twitch.tv
# https://rr3---sn-ci5gup-cagk.googlevideo.com
# https://rr7---sn-ci5gup-cagl.googlevideo.com
# https://rr7---sn-ci5gup-cagz.googlevideo.com
# https://rr2---sn-ci5gup-cags.googlevideo.com
# https://instagram.com
# https://rr1---sn-ci5gup-cagd.googlevideo.com
# https://rr3---sn-ci5gup-cags.googlevideo.com
# https://youtu.be
# https://IceSpice.lnk.to
# https://ikk...
# https://goo.gl
# https://www.y...
# https://rr4---sn-ci5gup-cagk.googlevideo.com
# https://ibighit.com
# https://shop.ive-starship.com
# https://www.nadiesabeloquevaapasarmanana.com
# https://rr6---sn-ci5gup-cags.googlevideo.com
# https://whatsapp.com
# https://rr4---sn-ci5gup-cag6.googlevideo.com
# https://rr1---sn-ci5gup-cagz.googlevideo.com
# https://rr6---sn-ci5gup-cagk.googlevideo.com
# https://rr4---sn-ci5gup-cagd.googlevideo.com
# https://mahakatha.co
# https://www.googleapis.com
# https://www.techequitycollective.com
# https://developers.googleblog.com
# https://cloud.google.com
# https://developer.android.com
# https://codelabs.developers.google.com
# https://firebase.google.com
# https://www.tensorflow.org
# https://developer.chrome.com
# https://play.google.com
# https://developers.generativeai.google
# https://flutter.dev
# https://ads.google.com
# https://www.kaggle.com
# https://angular.io
# http://d.android.com
# https://blog.google
# https://idx.dev
# https://developers-dot-devsite-v2-prod.appspot.com
# https://fonts.googleapis.com
# https://developerscontentserving-pa.clients6.google.com
# https://developerscontentsearch-pa.clients6.google.com
# https://families.google
# https://myaccount.google.com
# https://lh3.googleusercontent.com
# https://one.google.com
# https://about.google
# https://cdnjs.cloudflare.com
# https://fonts.gstatic.com
# https://ssl.gstatic.com
# http://support.google.com
# https://google.com
# https://fiber.google.com
# https://web-assets.waze.com
# https://services.google.com
# https://storage.googleapis.com
# https://payments.google.com
# http://www.google.com
# https://clients6.google.com
# https://content-googleapis-staging.sandbox.google.com
# https://content-googleapis-test.sandbox.google.com
# https://moltron-pa.clients6.google.com
# https://maps.google.co.in
# https://news.google.com
# https://mail.google.com
# https://drive.google.com
# http://www.google.co.in
# https://i9.ytimg.com
# https://s.ytimg.com
# https://browsehappy.com
# https://nexaexperience.com
# https://static.cdninstagram.com
# https://docrdsfx76ssb.cloudfront.net
# https://bitly.com
# https://cdn.cookielaw.org
# https://dev.bitly.com
# https://support.bitly.com
# http://super-long-link.com
# https://public.profitwell.com
# https://www.linkfire.com
# https://25446013.fs1.hubspotusercontent-eu1.net
# https://www.clickcease.com
# https://linkfire.scaletrk.com
# https://help.linkfire.com
# https://partners.linkfire.com
# https://advertise.linkfire.com
# https://corporate.linkfire.com
# https://app.linkfire.com
# https://marketing.lnk.to
# https://static.hsappstatic.net
# https://app-eu1.hubspot.com
# https://cp-eu1.hubspot.com
# https://accounts.tatadigital.com
# https://media.croma.com
# https://assets.adobedtm.com
# https://media.flixcar.com
# https://maps.googleapis.com
# http://ysprod.croma.com
# https://accounts.croma.com
# https://assets.croma.com
# https://livevideo.croma.com
# https://public.releases.juspay.in
# https://api.tatadigital.com
# https://plus.google.com
# https://s.go-mpulse.net
# https://s2.go-mpulse.net
# https://media-ik.croma.com
# https://dev8-pwa.croma.com
# https://preprod-pwa.croma.com
# https://croma.com
# https://api.croma.com
# http://vle.cscestore.in
# https://vle.cscestore.in
# https://archive.org
# https://purl.archive.org
# http://archive.org
# https://safety.google
# https://account.google.com
# https://transparency.google
# https://wac-cdn.atlassian.com
# https://metal.prod.atl-paas.net
# https://marketplace.atlassian.com
# https://confluence.atlassian.com
# https://developer.atlassian.com
# https://support.atlassian.com
# https://events.atlassian.com
# https://my.atlassian.com
# https://www.atlassianfoundation.org
# https://investors.atlassian.com
# https://atl-global.atlassian.com
# http://manage.statuspage.io
# http://status.digitalocean.com
# http://status.dropbox.com
# http://status.intercom.com
# https://manage.statuspage.io
# http://ogp.me
# https://atl-onetrust-wrapper.atlassian.com
# https://cdn.optimizely.com
# https://boxy-svg.com
# https://ace.atlassian.com
# https://university.atlassian.com
# https://id.atlassian.com
# https://httpwg.github.io
# https://www.ietf.org
# http://lists.w3.org
# https://wiki.css-houdini.org
# http://rdfa.info
# http://esw.w3.org
# https://w3c.studio24.net
# http://www.ics.uci.edu
# https://validator.w3.org
# http://pso.icann.org
# http://dev.w3.org
# http://tools.ietf.org
# http://www.ietf.org
# http://iswc07.org
# http://www.multilingualweb.eu
# http://tap.stanford.edu
# http://www.webplatform.org
# http://jigsaw.w3.org
# http://lcweb.loc.gov
# https://wordpress.org
# https://mastodon.social
# https://freshstore.co
# https://blog.joinmastodon.org
# https://docs.joinmastodon.org
# https://patreon.com
# https://donate.stripe.com
# https://www.fastly.com
# https://www.postmarkapp.com
# https://mobi.com
# https://medium.com
# https://lickability.com
# https://www.ramotion.com
# https://airvpn.org
# https://www.firesticktricks.com
# https://papersowl.com
# https://sextoycollective.com
# https://www.sister-sites.co.uk
# https://masto.host
# https://www.auscasinos.net
# https://www.nettikasinot.org
# https://wideangle.co
# https://www.noneedtostudy.com
# https://krystal.uk
# https://www.raspberrypi.com
# https://www.zerotier.com
# https://www.goldeneaglecoin.com
# https://rubycentral.org
# https://opalstack.com
# https://allbursaries.co.za
# https://theoatmeal.com
# https://www.completewebresources.com
# https://intellifluence.com
# https://toot.io
# https://www.4kdownload.com
# https://veepn.com
# https://werd.io
# https://mask.io
# https://joinmastodon.instatus.com
# https://cdn.cms-twdigitalassets.com
# https://apps.apple.com
# https://status.twitterstat.us
# https://publish.twitter.com
# https://privacy.twitter.com
# https://transparency.twitter.com
# https://about.twitter.com
# https://blog.twitter.com
# https://careers.twitter.com
# https://investor.twitterinc.com
# https://create.twitter.com
# https://preferencecenter.twitter.com
# https://developer.twitter.com
# https://twittercommunity.com
# https://marketing.twitter.com
# https://www.twitterflightschool.com
# https://platform.twitter.com
# https://ads.twitter.com
# https://s1259914507.t.eloqua.com
# https://verified.twitter.com
# https://cdn.rollbar.com
# https://uptimerobot.com
# https://js.maxmind.com
# https://www.github.com
# https://securitylab.github.com
# https://marketplace.visualstudio.com
# https://npmjs.com
# https://status.npmjs.com
# https://www.npmjs.com
# https://html.spec.whatwg.org
# https://www.cloudflare.com
# https://fly.io
# http://fb.me
# https://fb.me
# https://developer.wordpress.org
# https://s.w.org
# https://login.wordpress.org
# https://openverse.org
# https://learn.wordpress.org
# https://wordpress.tv
# https://make.wordpress.org
# https://central.wordcamp.org
# https://www.meetup.com
# https://jobs.wordpress.net
# https://mercantile.wordpress.org
# https://codex.wordpress.org
# https://wordpressfoundation.org
# https://buddypress.org
# https://bbpress.org
# https://wordpress.com
# https://ma.tt
# https://publiccode.eu
# https://www.x.com
# http://wp.me
# https://s1.wp.com
# https://fonts-api.wp.com
# https://wpvip.com
# https://wpcom.files.wordpress.com
# https://w.link
# https://href.li
# https://developer.wordpress.com
# https://automattic.com
# https://pixel.wp.com
# https://platform9p2.wordpress.com
# https://www.clarity.ms
# https://developer.mozilla.org
# https://public-api.wordpress.com
# https://docs.oracle.com
# https://login.eloqua.com
# https://www.oracle.com
# https://secure.gravatar.com
# http://electronjs.org
# https://d3js.org
# http://dojotoolkit.org
# http://www.sencha.com
# http://hammerjs.github.io
# http://jquery.com
# http://jquerymobile.com
# http://jqueryui.com
# https://listjs.com
# https://modelviewer.dev
# http://mootools.net
# http://prototypejs.org
# http://script.aculo.us
# http://youtube.github.io
# http://threejs.org
# http://msdn.microsoft.com
# https://creativecommons.org
# https://www.apache.org
# http://groups.google.com
# https://www.jsdelivr.com
# https://data.jsdelivr.com
# https://datum.jsdelivr.com
# https://jsdelivr.us11.list-manage.com
# https://gcore.com
# https://ns1.com
# https://render.com
# https://bunny.net
# https://www.algolia.com
# https://esm.run
# https://dakulov.com
# https://status.jsdelivr.com
# https://api.globalping.io
# https://opensourcefriday.com
# https://cdn.usefathom.com
# https://s3.amazonaws.com
# http://www.microsoft.com
# https://a.storyblok.com
# http://feeds.feedburner.com
# https://kit.fontawesome.com
# https://library.octopus.com
# https://roadmap.octopus.com
# https://help.octopus.com
# https://shop.octopus.com
# https://handbook.octopus.com
# https://streamyard.com
# https://status.octopus.com
# https://get.octopus.com
# https://imgix.datadoghq.com
# https://consent.trustarc.com
# https://d88f3ym7dkyv7.cloudfront.net
# https://corpsite-staging.datadoghq.com
# https://docs.datadoghq.com
# https://partners.datadoghq.com
# https://careers.datadoghq.com
# https://investors.datadoghq.com
# https://securitylabs.datadoghq.com
# https://app.datadoghq.com
# https://player.vimeo.com
# https://learn.datadoghq.com
# https://px.ads.linkedin.com
# https://res.cloudinary.com
# https://developer.evinced.com
# https://knowledge.evinced.com
# https://hub.evinced.com
# https://ogp.me
# https://static.redhat.com
# https://www.drupal.org
# https://access.redhat.com
# https://cloud.redhat.com
# https://developers.redhat.com
# https://catalog.redhat.com
# https://connect.redhat.com
# https://marketplace.redhat.com
# https://learn.redhat.com
# https://www.ansible.com
# https://skills.ole.redhat.com
# https://sso.redhat.com
# https://fortune.com
# https://coolstuff.redhat.com
# https://chrome.google.com
# https://blog.1password.com
# https://www.1password.university
# https://support.1password.com
# https://1password.community
# https://start.1password.com
# https://videos.ctfassets.net
# https://watchtower.1password.com
# https://randombutmemorable.simplecast.com
# https://passage.1password.com
# https://1password.social
# https://www.reddit.com
# https://assets-global.website-files.com
# https://j.6sc.co
# http://www.endorlabs.com
# https://riskexplorer.endorlabs.com
# https://endor.wistia.com
# https://embed-ssl.wistia.com
# https://d3e54v103j8qbb.cloudfront.net
# https://snap.licdn.com
# https://uploads-ssl.webflow.com
# https://docs.pixee.ai
# https://blog.pixee.ai
# https://app.pixee.ai
# https://codemodder.io
# https://zachholman.com
# http://tackle.io
# https://devrev.ai
# https://www.hackerone.com
# https://www.nimidev.com
# https://www.agitp.com
# https://linkedin.com
# https://join.slack.com
# http://gmpg.org
# https://trk.techtarget.com
# https://dev.visualwebsiteoptimizer.com
# https://static.addtoany.com
# https://js.driftt.com
# https://www.schema.org
# https://docs.mend.io
# https://forms.forgetthefunnel.com
# https://disposable.debounce.io
# https://marketo.clearbit.com
# https://6967988f564f4347b438eea799712c33.js.ubembed.com
# https://wp-rocket.me
# https://be.tricentis.com
# https://www.googleoptimize.com
# https://support-hub.tricentis.com
# https://shiftsync.tricentis.com
# https://documentation.tricentis.com
# https://feedback.tricentis.com
# https://events.tricentis.com
# https://www.devopsparadox.com
# https://static.trunk.io
# https://docs.trunk.io
# https://calendly.com
# https://app.trunk.io
# https://features.trunk.io
# https://slack.trunk.io
# https://status.trunk.io
# https://www.paypalobjects.com
# https://newsroom.in.paypal-corp.com
# https://developer.paypal.com
# https://t.paypal.com
# https://careers.pypl.com
# http://en.wikipedia.org
# https://assets.website-files.com
# https://www.iubenda.com
# https://cdn.iubenda.com
# https://staging.bsky.app
# https://webflow.com
# https://boxops.io
# https://www.ibm.com
# https://www.hashicorp.com
# https://marketingplatform.google.com
# https://www.wikidata.org
# https://www.blog.google
# https://analytics.google.com
# https://skillshop.withgoogle.com
# https://www.yourprimer.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\DSA\webcrawler.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> crawler = WebCrawler()
# ----> <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> crawler.crawl('https://neetcode.io')
#
# c:\DSA\webcrawler.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> print(actual_url)
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a> # This is the raw HTML representation of the website (URL)
# ---> <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> actual_url_html = self.read_raw_html(actual_url)
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a> if actual_url_html:
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a>     for url in self.get_links_from_html(actual_url_html):
#
# c:\DSA\webcrawler.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a> raw_html = " "
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=28'>29</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=29'>30</a>     response = request.urlopen(url)
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=30'>31</a>     raw_html = response.read().decode('utf-8')
#      <a href='vscode-notebook-cell:/c%3A/DSA/webcrawler.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a> except Exception as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1283 def request(self, method, url, body=None, headers={}, *,
#    1284             encode_chunked=False):
#    1285     """Send a complete request to the server."""
# -> 1286     self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328 if isinstance(body, str):
#    1329     # RFC 2616 Section 3.7.1 says that text default has a
#    1330     # default charset of iso-8859-1.
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279 else:
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 msg = b"\r\n".join(self._buffer)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#    1046     if hasattr(message_body, 'read'):
#    1047         # Let file-like take precedence over byte-like.  This
#    1048         # is needed to allow the current position of mmap'ed
#    1049         # files to be taken into account.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:979, in HTTPConnection.send(self, data)
#     977 if self.sock is None:
#     978     if self.auto_open:
# --> 979         self.connect()
#     980     else:
#     981         raise NotConnected()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1458, in HTTPSConnection.connect(self)
#    1455 else:
#    1456     server_hostname = self.host
# -> 1458 self.sock = self._context.wrap_socket(self.sock,
#    1459                                       server_hostname=server_hostname)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1105         if timeout == 0.0:
#    1106             # non-blocking
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#    1110     self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1379, in SSLSocket.do_handshake(self, block)
#    1377     if timeout == 0.0 and block:
#    1378         self.settimeout(None)
# -> 1379     self._sslobj.do_handshake()
#    1380 finally:
#    1381     self.settimeout(timeout)
#
# KeyboardInterrupt:
